# %%
from pydantic import BaseModel, Field
from typing import List, Optional
from uuid import uuid4

# %%
class RestaurantBase(BaseModel):
    name: str
    city: str
    capacity: int

# %%
RestaurantBase(
    name="Panda Express",
    city="CDMX",
    capacity=100
    )
# Out:
# RestaurantBase(name='Panda Express', city='CDMX', capacity=100)

# %%
class Client(BaseModel):
    name: str
    email: str
    age: Optional[int] = None

# %%
client1 = Client(name="César Zamora",email="cesar.zammar@tecmilenio.mx")

# %%
client2 = Client(name="César Zamora",email="cesar.zammar@tecmilenio.mx",age=40)
