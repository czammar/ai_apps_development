# %%
from pydantic import BaseModel, Field
from typing import List, Optional
from uuid import uuid4

# %%
class RestaurantBase(BaseModel):
    name: str
    city: str
    capacity: float

# %%
RestaurantBase(
    name="Panda Express",
    city="CDMX",
    capacity=50
    )
# Out:
# RestaurantBase(name='Panda Express', city='CDMX', capacity=50.0)

# %%
class Client(BaseModel):
    name: str
    email: str
    age: Optional[int] = None

# %%
client1 = Client(name="César Zamora",email="cesar.zammar@tecmilenio.mx",age=38)

# %%
client2 = Client(name="Carlos Zamora",email="carlos.zammar@tecmilenio.mx")

# %%
client1.age
# Out:
# 38

# %%
client2.age
